# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('./data/Train/2012/2012_cites.csv')

# %%
train.shape
# Out:
# (2025, 11839)

# %%
train.sum().sort_values().tail(30).plot(kind='barh', figsize=(6,9))

# %%
train.sum().sort_values().tail(30)
# Out:
# Fourteenth Amendment                       71
# 421 F.3d 125                               72
# 42 U.S.C. § 2000                           73
# Sixth Amendment                            75
# 552 U.S. 38                                76
# First Amendment                            78
# 550 U.S. 544                               81
# 8 C.F.R. § 1208                            84
# 321 F.3d 292                               88
# Fed. R. Civ. P. 56                         88
# 426 F.3d 520                              100
# Title VII                                 100
# 514 F.3d 233                              102
# 556 U.S. 662                              107
# 430 F.3d 77                               111
# 18 U.S.C. § 3553                          112
# 448 F.3d 515                              126
# 534 F.3d 162                              130
# 417 F.3d 268                              137
# 550 F.3d 180                              138
# ...

# %%
sns.distplot(train.sum(axis=1), kde=False, bins=91)
plt.title('Citation Distribution')
# Out:
# Text(0.5,1,u'Citation Distribution')

# %%
test = pd.read_csv('./data/test/2015/2015X1_targetscore.csv')

# %%
sns.distplot(test, kde=False, axlabel='Score')
plt.title('Case Score Distribution')
# Out:
# Text(0.5,1,u'Case Score Distribution')
